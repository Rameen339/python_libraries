# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)
x1=pd.DataFrame({'x':x,'y':y})
sns.lineplot(x='x',y='y',data=x1)
plt.show()

# %%
y1=sns.load_dataset('penguins')
y1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x='bill_length_mm',y='flipper_length_mm',data=y1,hue='sex')
plt.legend()
plt.show()

# %%
sns.lineplot(x='bill_length_mm',y='flipper_length_mm',data=y1,hue='sex',style='sex',palette='Accent',markers=['>','o'])#palette can be 'Accent','Deep',Dark'
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt    
import seaborn as sns
y1=sns.load_dataset('penguins').head()
sns.lineplot(x='bill_length_mm',y='flipper_length_mm',data=y1,hue='sex',dashes=False,color='red')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt    
import seaborn as sns
y1=sns.load_dataset('penguins')
y1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x='species',y='bill_depth_mm',data=y1,hue="sex",ci=100  )     #sns.barplot(x='bill_depth_mm',y='species',data=y1)
plt.grid()
plt.show()   
                                                                           #order_1=(x='Chinstrap species','Gentoo','Adelie')
                                                                           #order=order_1,hue_order=['Female','Male']
# Out:
# C:\Users\is\AppData\Local\Temp\ipykernel_9140\3240270610.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='species',y='bill_depth_mm',data=y1,hue="sex",ci=100  )     #sns.barplot(x='bill_depth_mm',y='species',data=y1)

# %%
sns.barplot(x='body_mass_g',y='bill_depth_mm',data=y1,hue="sex",orient='v',palette='icefire',saturation=1000,errcolor='red',errwidth=3,capsize=0.5,dodge=False
            ,alpha=0.5 )    
 #orientation parameter is only used for two numerical data types
 #dodge=True/False is used to separate the value of hue
plt.grid()
plt.show()
# Out:
# C:\Users\is\AppData\Local\Temp\ipykernel_9140\2265859227.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'red'}` instead.
#
#   sns.barplot(x='body_mass_g',y='bill_depth_mm',data=y1,hue="sex",orient='v',palette='icefire',saturation=1000,errcolor='red',errwidth=3,capsize=0.5,dodge=False
# C:\Users\is\AppData\Local\Temp\ipykernel_9140\2265859227.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 3}` instead.
#
#   sns.barplot(x='body_mass_g',y='bill_depth_mm',data=y1,hue="sex",orient='v',palette='icefire',saturation=1000,errcolor='red',errwidth=3,capsize=0.5,dodge=False

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
sns.displot(y1['bill_length_mm'],bins=[35,40,45,50,55,60],kde=True,rug= True,color='g')#log_scale=True
plt.show()

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
m={'Male':"*",'Female':'o'}
sns.scatterplot(x='body_mass_g',y='bill_depth_mm',data=y1,hue='sex',size='sex',sizes=(200,100),palette='icefire',markers=m)
plt.show()

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
var=np.linspace(0,10,20).reshape(4,5)
var
sns.heatmap(var)
# Out:
# <Axes: >

# %%
y1=sns.load_dataset('anagrams')
y2=y1.drop(columns=['attnr'],axis=1)
sns.heatmap(y2,vmax=12,cmap='icefire',annot=True)
# Out:
# <Axes: >

# %%
var=np.linspace(0,10,10).reshape(2,5)
var
# Out:
# array([[ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444],
#        [ 5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ]])

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
y={'fontsize':10,'color':'red'}
y1=sns.load_dataset('anagrams')
y2=y1.drop(columns=['attnr'],axis=1)
ar=np.array([["a0",'a1','a2','a3','a4'],
            ['b0','b1','b2','b3','b4']])
p=sns.heatmap(var,vmin=0,vmax=10,cmap='PuOr',annot=ar,fmt='s',annot_kws=y,linewidth=4,linecolor='black',cbar=True,xticklabels=True)
p.set(xlabel='python',ylabel='numpy')
sns.set(font_scale=0.6)
plt.show()

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
var=sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='sex',data=var,hue='smoker',color='red',saturation=0.6)                          # to make it horizoontal use y
# Out:
# C:\Users\is\AppData\Local\Temp\ipykernel_9140\2330420720.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.countplot(x='sex',data=var,hue='smoker',color='red',saturation=0.6)                          # to make it horizoontal use y
# <Axes: xlabel='sex', ylabel='count'>

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
var=sns.load_dataset('tips')
var 

var=sns.violinplot(x='day',y='tip',data=var,hue='time',linewidth=2,palette='Dark2')
plt.show()

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
var=sns.load_dataset('tips')
var 

var=sns.violinplot(x='time',y='total_bill',data=var,hue='time',linewidth=2,palette='Dark2',order=['Dinner','Lunch'],split=True,scale='count',inner='stick')
plt.show()
# Out:
# C:\Users\is\AppData\Local\Temp\ipykernel_9140\676039401.py:8: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   var=sns.violinplot(x='time',y='total_bill',data=var,hue='time',linewidth=2,palette='Dark2',order=['Dinner','Lunch'],split=True,scale='count',inner='stick')

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
var=sns.load_dataset('tips')
var
sns.pairplot(var,vars=['total_bill','tip'],hue='sex',hue_order=['Female','Male'],palette='BuGn',kind='kde',markers=['o','*'])

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
var=sns.load_dataset('tips')
sns.stripplot(x='day',y='total_bill',data=var,hue='sex',palette='rocket_r',linewidth=1,edgecolor='black',jitter=0.1,size=10,marker='*')
plt.show()

# %%
sns.stripplot(x=var['total_bill'],color='red')
# Out:
# <Axes: xlabel='total_bill'>

# %%
var=sns.load_dataset('tips')
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=var,hue='time',color='magenta',order=['Thur','Fri','Sat','Sun'],showmeans=True,meanprops={'marker':'*','markeredgecolor':'black'},linewidth=3
            ,orient='v',palette='plasma')
plt.show()

# %%
import matplotlib.pyplot as plt    
import seaborn as sns
import pandas as pd
import numpy as np
var=sns.load_dataset('tips').head(20)
var
sns.catplot(x='total_bill',y='day',data=var,hue='sex',palette='BuPu',height=3,kind='bar')
